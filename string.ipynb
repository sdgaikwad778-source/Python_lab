# %%
text = input("Enter the String")
# Out:
# Enter the String:  Deogiri

# %%
upper = 0
lower = 0

# %%
for ch in text:
    if ch.isupper():
        upper +=1
    elif ch.islower():
        lower +=1

# %%
print("UpperCase letters: ", upper)
print("LowerCase letters: ", lower)
# Out:
# UpperCase letters:  1
# LowerCase letters:  6
